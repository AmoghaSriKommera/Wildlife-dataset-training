# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 29.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 55.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 32.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 43.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !unzip /content/drive/MyDrive/wildlife_dataset_training.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/wildlife_dataset_training.zip
#    creating: /content/wildlife_dataset_training/african-wildlife/
#    creating: /content/wildlife_dataset_training/african-wildlife/test/
#    creating: /content/wildlife_dataset_training/african-wildlife/test/images/
#   inflating: /content/wildlife_dataset_training/african-wildlife/test/images/1 (103).jpg
#   inflating: /content/wildlife_dataset_training/african-wildlife/test/images/1 (121).jpg
#   inflating: /content/wildlife_dataset_training/african-wildlife/test/images/1 (128).jpg
#   inflating: /content/wildlife_dataset_training/african-wildlife/test/images/1 (130).jpg
#   inflating: /content/wildlife_dataset_training/african-wildlife/test/images/1 (131).jpg
#   inflating: /content/wildlife_dataset_training/african-wildlife/test/images/1 (137).jpg
#   inflating: /content/wildlife_dataset_training/african-wildlife/test/images/1 (144).jpg
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # or yolov8s.pt, yolov8m.pt depending on your needs
model.train(
    data='/content/wildlife_dataset_training/data.yaml',
    epochs=12,
    imgsz=640
)
# Out:
# Ultralytics 8.3.155 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# %%writefile /content/wildlife_dataset_training/data.yaml
# train: /content/wildlife_dataset_training/african-wildlife/train/images
# val: /content/wildlife_dataset_training/african-wildlife/val/images
#
# nc: 5
# names: ['lion', 'elephant', 'zebra', 'giraffe', 'rhino']  # change if needed
# Out:
# Overwriting /content/wildlife_dataset_training/data.yaml

# %%
# !cp /content/runs/detect/train/weights/best.pt /content/drive/MyDrive/
# Out:
# cp: cannot stat '/content/runs/detect/train/weights/best.pt': No such file or directory

# %%
# %%writefile /content/wildlife_dataset_training/data.yaml
# train: /content/wildlife_dataset_training/african-wildlife/train/images
# val: /content/wildlife_dataset_training/african-wildlife/val/images
#
# nc: 5
# names: ['lion', 'elephant', 'zebra', 'giraffe', 'rhino']  # adjust if neede
# Out:
# Overwriting /content/wildlife_dataset_training/data.yaml

# %%
# !ls /content/wildlife_dataset_training/african-wildlife/val/images
# Out:
# '1 (102).jpg'  '1 (366).jpg'  '2 (289).jpg'  '3 (215).jpg'  '4 (172).jpg'
# '1 (111).jpg'  '1 (367).jpg'  '2 (28).jpg'   '3 (221).jpg'  '4 (175).jpg'
# '1 (120).jpg'  '1 (369).jpg'  '2 (297).jpg'  '3 (226).jpg'  '4 (181).jpg'
# '1 (122).jpg'  '1 (39).jpg'   '2 (29).jpg'   '3 (227).jpg'  '4 (186).jpg'
# '1 (127).jpg'  '1 (3).jpg'    '2 (311).jpg'  '3 (234).jpg'  '4 (193).jpg'
# '1 (136).jpg'  '1 (40).jpg'   '2 (312).jpg'  '3 (248).jpg'  '4 (197).jpg'
# '1 (138).jpg'  '1 (48).jpg'   '2 (331).jpg'  '3 (257).jpg'  '4 (211).jpg'
# '1 (145).jpg'  '1 (51).jpg'   '2 (332).jpg'  '3 (263).jpg'  '4 (231).jpg'
# '1 (149).jpg'  '1 (54).jpg'   '2 (337).jpg'  '3 (269).jpg'  '4 (239).jpg'
# '1 (159).jpg'  '1 (5).jpg'    '2 (345).jpg'  '3 (273).jpg'  '4 (246).jpg'
# '1 (15).jpg'   '1 (61).jpg'   '2 (351).jpg'  '3 (293).jpg'  '4 (262).jpg'
# '1 (162).jpg'  '1 (62).jpg'   '2 (355).jpg'  '3 (294).jpg'  '4 (271).jpg'
# '1 (170).jpg'  '1 (6).jpg'    '2 (358).jpg'  '3 (295).jpg'  '4 (278).jpg'
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
model.train(data='/content/wildlife_dataset_training/data.yaml', epochs=12, imgsz=640)
# Out:
# Ultralytics 8.3.155 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cp /content/runs/detect/train/weights/best.pt /content/best.pt
# Out:
# cp: cannot stat '/content/runs/detect/train/weights/best.pt': No such file or directory

# %%
# !ls -R /content/runs/detect/
# Out:
# /content/runs/detect/:
# train  train2  train3  train4
#
# /content/runs/detect/train:
# args.yaml  weights
#
# /content/runs/detect/train/weights:
#
# /content/runs/detect/train2:
# args.yaml  weights
#
# /content/runs/detect/train2/weights:
#
# /content/runs/detect/train3:
# args.yaml			 R_curve.png	     train_batch2.jpg
# confusion_matrix_normalized.png  results.csv	     val_batch0_labels.jpg
# confusion_matrix.png		 results.png	     val_batch0_pred.jpg
# F1_curve.png			 train_batch0.jpg    val_batch1_labels.jpg
# labels_correlogram.jpg		 train_batch132.jpg  val_batch1_pred.jpg
# labels.jpg			 train_batch133.jpg  val_batch2_labels.jpg
# P_curve.png			 train_batch134.jpg  val_batch2_pred.jpg
# PR_curve.png			 train_batch1.jpg    weights
#
# /content/runs/detect/train3/weights:
# best.pt  last.pt
#
# /content/runs/detect/train4:
# args.yaml			 R_curve.png	     train_batch2.jpg
# confusion_matrix_normalized.png  results.csv	     val_batch0_labels.jpg
# ...

# %%
# !cp /content/runs/detect/train4/weights/best.pt /content/best.pt

# %%
from ultralytics import YOLO

model = YOLO('/content/runs/detect/train4/weights/best.pt')
metrics = model.val()

# Access mAP, precision, recall, etc.
print(metrics.box.map)         # mAP@0.5
print(metrics.box.map50)       # mAP@0.5
print(metrics.box.map75)       # mAP@0.75
print(metrics.box.maps)        # mAP for each class
# Out:
# Ultralytics 8.3.155 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1538.3±1038.0 MB/s, size: 99.8 KB)
# val: Scanning /content/wildlife_dataset_training/african-wildlife/val/labels.cache... 225 images, 0 backgrounds, 0 corrupt: 100%|██████████| 225/225 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:03<00:00,  4.83it/s]
#                    all        225        379      0.946       0.85      0.938      0.762
#                   lion         62         89      0.974      0.847      0.947      0.769
#               elephant         53         91      0.905      0.846      0.903      0.721
#                  zebra         55         85      0.937      0.881      0.946      0.823
# ...
